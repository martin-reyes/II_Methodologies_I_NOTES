# %% [markdown]
# # Time Series

# %% [markdown]
# ### Acquisition

# %% [markdown]
# ### Working with Time Series Data

# %% [markdown]
# ### Preparation

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Modeling
